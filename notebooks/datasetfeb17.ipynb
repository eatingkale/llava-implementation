# %% [markdown]
# # feb 17

# %% [markdown]
# - https://github.com/TRI-ML/prismatic-vlms/blob/main/prismatic/preprocessing/download.py#L53
# - https://huggingface.co/datasets/liuhaotian/LLaVA-Instruct-150K/discussions/15

# %%
from datasets import load_dataset
dataset = load_dataset("liuhaotian/LLaVA-Instruct-150K", split="train")
# Out:
# Generating train split: 394276 examples [3:45:31, 29.14 examples/s]
# ---------------------------------------------------------------------------
# ArrowInvalid                              Traceback (most recent call last)
# File ~/Documents/Liquid/llava-implementation/.venv/lib/python3.11/site-packages/datasets/packaged_modules/json/json.py:159, in Json._generate_tables(self, base_files, files_iterables)
#     158 try:
# --> 159     pa_table = paj.read_json(
#     160         io.BytesIO(batch), read_options=paj.ReadOptions(block_size=block_size)
#     161     )
#     162     break
#
# File ~/Documents/Liquid/llava-implementation/.venv/lib/python3.11/site-packages/pyarrow/_json.pyx:342, in pyarrow._json.read_json()
#
# File ~/Documents/Liquid/llava-implementation/.venv/lib/python3.11/site-packages/pyarrow/error.pxi:155, in pyarrow.lib.pyarrow_internal_check_status()
#
# ...

# %%
import sys
sys.path.append("..")
from main import LLaVADataset
LLaVADataset
# Out:
# main.LLaVADataset

# %%
dataset = LLaVADataset()
# Out:
# Generating train split: 394276 examples [02:14, 2933.14 examples/s]
# ---------------------------------------------------------------------------
# ArrowInvalid                              Traceback (most recent call last)
# File ~/Documents/Liquid/llava-implementation/.venv/lib/python3.11/site-packages/datasets/packaged_modules/json/json.py:159, in Json._generate_tables(self, base_files, files_iterables)
#     158 try:
# --> 159     pa_table = paj.read_json(
#     160         io.BytesIO(batch), read_options=paj.ReadOptions(block_size=block_size)
#     161     )
#     162     break
#
# File ~/Documents/Liquid/llava-implementation/.venv/lib/python3.11/site-packages/pyarrow/_json.pyx:342, in pyarrow._json.read_json()
#
# File ~/Documents/Liquid/llava-implementation/.venv/lib/python3.11/site-packages/pyarrow/error.pxi:155, in pyarrow.lib.pyarrow_internal_check_status()
#
# ...

# %%
# It really seems we have to download locally:
import os

load_path = '../data/'
dataset = load_dataset("json", data_files=os.path.join(load_path, 'llava_instruct_150k.json'))
# Out:
# Generating train split: 157712 examples [00:11, 13484.14 examples/s]

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'image', 'conversations'],
#         num_rows: 157712
#     })
# })
